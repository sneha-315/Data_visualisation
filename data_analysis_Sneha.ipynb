# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\KIIT0001\Downloads\customers-100.csv")
print(data.head(10))
# Out:
#    Index      Customer Id First Name  Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl     Baxter
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 4      5  053d585Ab6b3159     Joanna     Bender
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
# 5                     Steele Group      Chavezborough
# ...

# %%
data.shape
# Out:
# (100, 12)

# %%
data.columns
# Out:
# Index(['Index', 'Customer Id', 'First Name', 'Last Name', 'Company', 'City',
#        'Country', 'Phone 1', 'Phone 2', 'Email', 'Subscription Date',
#        'Website'],
#       dtype='object')

# %%
data['Customer Id']
# Out:
# 0     DD37Cf93aecA6Dc
# 1     1Ef7b82A4CAAD10
# 2     6F94879bDAfE5a6
# 3     5Cef8BFA16c5e3c
# 4     053d585Ab6b3159
#            ...
# 95    cb8E23e48d22Eae
# 96    CeD220bdAaCfaDf
# 97    28CDbC0dFe4b1Db
# 98    c23d1D9EE8DEB0A
# 99    2354a0E336A91A1
# Name: Customer Id, Length: 100, dtype: object

# %%
data[['Customer Id','Company']]
# Out:
#         Customer Id                          Company
# 0   DD37Cf93aecA6Dc                  Rasmussen Group
# 1   1Ef7b82A4CAAD10                      Vega-Gentry
# 2   6F94879bDAfE5a6                    Murillo-Perry
# 3   5Cef8BFA16c5e3c  Dominguez, Mcmillan and Donovan
# 4   053d585Ab6b3159         Martin, Lang and Andrade
# ..              ...                              ...
# 95  cb8E23e48d22Eae                        Carey LLC
# 96  CeD220bdAaCfaDf            Ware, Burns and Oneal
# 97  28CDbC0dFe4b1Db                    Schmitt-Jones
# 98  c23d1D9EE8DEB0A               Fitzgerald-Harrell
# 99  2354a0E336A91A1               Le, Nash and Cross
#
# [100 rows x 2 columns]

# %%
data[['Customer Id','Company']].head(10)
# Out:
#        Customer Id                          Company
# 0  DD37Cf93aecA6Dc                  Rasmussen Group
# 1  1Ef7b82A4CAAD10                      Vega-Gentry
# 2  6F94879bDAfE5a6                    Murillo-Perry
# 3  5Cef8BFA16c5e3c  Dominguez, Mcmillan and Donovan
# 4  053d585Ab6b3159         Martin, Lang and Andrade
# 5  2d08FB17EE273F4                     Steele Group
# 6  EA4d384DfDbBf77     Lester, Woodard and Mitchell
# 7  0e04AFde9f225dE     Sanford, Davenport and Giles
# 8  C2dE4dEEc489ae0                   Browning-Simon
# 9  8C2811a503C7c5a                     Beck-Hendrix

# %%
data[1:10]
# Out:
#    Index      Customer Id First Name  Last Name  \
# 1      2  1Ef7b82A4CAAD10    Preston     Lozano
# 2      3  6F94879bDAfE5a6        Roy      Berry
# 3      4  5Cef8BFA16c5e3c      Linda      Olsen
# 4      5  053d585Ab6b3159     Joanna     Bender
# 5      6  2d08FB17EE273F4      Aimee      Downs
# 6      7  EA4d384DfDbBf77     Darren       Peck
# 7      8  0e04AFde9f225dE      Brett     Mullen
# 8      9  C2dE4dEEc489ae0     Sheryl     Meyers
# 9     10  8C2811a503C7c5a   Michelle  Gallagher
#
#                            Company               City  \
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
# 5                     Steele Group      Chavezborough
# 6     Lester, Woodard and Mitchell           Lake Ana
# 7     Sanford, Davenport and Giles            Kimport
# ...

# %%
data[1:10:3]
# Out:
#    Index      Customer Id First Name Last Name                       Company  \
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano                   Vega-Gentry
# 4      5  053d585Ab6b3159     Joanna    Bender      Martin, Lang and Andrade
# 7      8  0e04AFde9f225dE      Brett    Mullen  Sanford, Davenport and Giles
#
#                 City                     Country                 Phone 1  \
# 1  East Jimmychester                    Djibouti              5153435776
# 4     West Priscilla  Slovakia (Slovak Republic)  001-234-203-0635x76146
# 7            Kimport                    Bulgaria    001-583-352-7197x297
#
#                  Phone 2                    Email Subscription Date  \
# 1       686-620-1820x944          vmata@colon.com        2021-04-23
# 4  001-199-446-3860x3486  colinalvarado@miles.net        2021-04-17
# 7       001-333-145-0369          asnow@colon.com        2021-04-12
#
#                        Website
# 1        http://www.hobbs.com/
# ...

# %%
for index,rows in data.iterrows():
  print(index,rows['Company'])
# Out:
# 0 Rasmussen Group
# 1 Vega-Gentry
# 2 Murillo-Perry
# 3 Dominguez, Mcmillan and Donovan
# 4 Martin, Lang and Andrade
# 5 Steele Group
# 6 Lester, Woodard and Mitchell
# 7 Sanford, Davenport and Giles
# 8 Browning-Simon
# 9 Beck-Hendrix
# 10 Oconnell, Meza and Everett
# 11 Hoffman, Reed and Mcclain
# 12 Graham-Francis
# 13 Carpenter-Cook
# 14 Carter-Hancock
# 15 Singleton and Sons
# 16 Winters-Mendoza
# 17 Valentine LLC
# 18 Simon LLC
# 19 Mays-Mccormick
# 20 Patterson Inc
# 21 Manning, Hester and Arroyo
# 22 Greer and Sons
# 23 Watts-Donaldson
# 24 Tucker LLC
# 25 Giles Ltd
# 26 Simmons Group
# 27 Hinton, Chaney and Stokes
# 28 Santana-Duran
# 29 Sawyer PLC
# 30 Acosta, Petersen and Morrow
# 31 Mcgee Group
# 32 Adkins-Salinas
# 33 Herrera Group
# 34 Waters, Chase and Aguilar
# 35 Palmer, Barnes and Houston
# 36 Jordan Ltd
# 37 Glover and Sons
# 38 Huerta-Mclean
# 39 Anderson Ltd
# 40 Monroe PLC
# 41 Kaufman and Sons
# 42 Perkins-Trevino
# 43 Cross PLC
# ...

# %%
data.loc[1]
# Out:
# Index                                    2
# Customer Id                1Ef7b82A4CAAD10
# First Name                         Preston
# Last Name                           Lozano
# Company                        Vega-Gentry
# City                     East Jimmychester
# Country                           Djibouti
# Phone 1                         5153435776
# Phone 2                   686-620-1820x944
# Email                      vmata@colon.com
# Subscription Date               2021-04-23
# Website              http://www.hobbs.com/
# Name: 1, dtype: object

# %%
data.drop(columns="Company")
# Out:
#     Index      Customer Id First Name Last Name               City  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter       East Leonard
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano  East Jimmychester
# 2       3  6F94879bDAfE5a6        Roy     Berry      Isabelborough
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen         Bensonview
# 4       5  053d585Ab6b3159     Joanna    Bender     West Priscilla
# ..    ...              ...        ...       ...                ...
# 95     96  cb8E23e48d22Eae       Karl     Greer       East Richard
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson       New Bradview
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra         Ortegaland
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer    Lake Elijahview
# 99    100  2354a0E336A91A1   Clarence    Haynes          Judymouth
#
#                        Country                 Phone 1  \
# 0                        Chile            229.077.5154
# ...

# %%
data.drop(columns='Customer Id')
# Out:
#     Index First Name Last Name                          Company  \
# 0       1     Sheryl    Baxter                  Rasmussen Group
# 1       2    Preston    Lozano                      Vega-Gentry
# 2       3        Roy     Berry                    Murillo-Perry
# 3       4      Linda     Olsen  Dominguez, Mcmillan and Donovan
# 4       5     Joanna    Bender         Martin, Lang and Andrade
# ..    ...        ...       ...                              ...
# 95     96       Karl     Greer                        Carey LLC
# 96     97       Lynn  Atkinson            Ware, Burns and Oneal
# 97     98       Fred    Guerra                    Schmitt-Jones
# 98     99     Yvonne    Farmer               Fitzgerald-Harrell
# 99    100   Clarence    Haynes               Le, Nash and Cross
#
#                  City                     Country                 Phone 1  \
# 0        East Leonard                       Chile            229.077.5154
# ...

# %%
df=data.drop(columns='City')
print(df)
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company                     Country  \
# 0                   Rasmussen Group                       Chile
# 1                       Vega-Gentry                    Djibouti
# 2                     Murillo-Perry         Antigua and Barbuda
# 3   Dominguez, Mcmillan and Donovan          Dominican Republic
# ...
